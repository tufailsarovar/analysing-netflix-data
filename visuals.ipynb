# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('final_dataset.csv', sep=',', na_values=[''], quotechar='"')

# %%
df.head()

# %%
df.shape

# %%
plt.hist(df['release_year'])
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.show()

# %%
df.columns

# %%
plt.hist(df['type'])
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
counts = df['type'].value_counts()

plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
plt.show()

# %%
plt.hist(df['content_rating'])
plt.xlabel('Content Rating')
plt.ylabel('Count')
plt.show()

# %%
df.dtypes['country']
